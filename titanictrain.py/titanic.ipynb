# %%
import pandas as pd
import  numpy as np

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.rename(columns={'SibSp':'relatives'},inplace=True)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %% [markdown]
# access the colunm name

# %%
x = data['relatives']
print(x)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: relatives, Length: 891, dtype: int64

# %%
data.rename(columns={'PassengerId':'id'},inplace=True)
data
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
data.iloc[0,0:]
# Out:
# id                                 1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# relatives                          1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
# Name: 0, dtype: object

# %%
data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data.iloc[:,3:4]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
data.iloc[1:3,:]
# Out:
#    id  Survived  Pclass                                               Name  \
# 1   2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2   3         1       3                             Heikkinen, Miss. Laina
#
#       Sex   Age  relatives  Parch            Ticket     Fare Cabin Embarked
# 1  female  38.0          1      0          PC 17599  71.2833   C85        C
# 2  female  26.0          0      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.iloc[-5:,:]
# Out:
#       id  Survived  Pclass                                      Name     Sex  \
# 886  887         0       2                     Montvila, Rev. Juozas    male
# 887  888         1       1              Graham, Miss. Margaret Edith  female
# 888  889         0       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 889  890         1       1                     Behr, Mr. Karl Howell    male
# 890  891         0       3                       Dooley, Mr. Patrick    male
#
#       Age  relatives  Parch      Ticket   Fare Cabin Embarked
# 886  27.0          0      0      211536  13.00   NaN        S
# 887  19.0          0      0      112053  30.00   B42        S
# 888   NaN          1      2  W./C. 6607  23.45   NaN        S
# 889  26.0          0      0      111369  30.00  C148        C
# 890  32.0          0      0      370376   7.75   NaN        Q

# %%
data.loc[0,"Name"]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
data.loc[0:4,['Age','Sex','Name']]
# Out:
#     Age     Sex                                               Name
# 0  22.0    male                            Braund, Mr. Owen Harris
# 1  38.0  female  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0  female                             Heikkinen, Miss. Laina
# 3  35.0  female       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0    male                           Allen, Mr. William Henry

# %%
data.loc[data["Age"]==50,:]
# Out:
#       id  Survived  Pclass                                             Name  \
# 177  178         0       1                       Isham, Miss. Ann Elizabeth
# 259  260         1       2                      Parrish, Mrs. (Lutie Davis)
# 299  300         1       1  Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 434  435         0       1                        Silvey, Mr. William Baird
# 458  459         1       2                              Toomey, Miss. Ellen
# 482  483         0       3                         Rouse, Mr. Richard Henry
# 526  527         1       2                             Ridsdale, Miss. Lucy
# 544  545         0       1                       Douglas, Mr. Walter Donald
# 660  661         1       1                    Frauenthal, Dr. Henry William
# 723  724         0       2                          Hodges, Mr. Henry Price
#
#         Sex   Age  relatives  Parch        Ticket      Fare    Cabin Embarked
# ...

# %%
data.loc[(data["Age"]==50)&(data["Sex"]=="female")]
# Out:
#       id  Survived  Pclass                                             Name  \
# 177  178         0       1                       Isham, Miss. Ann Elizabeth
# 259  260         1       2                      Parrish, Mrs. (Lutie Davis)
# 299  300         1       1  Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 458  459         1       2                              Toomey, Miss. Ellen
# 526  527         1       2                             Ridsdale, Miss. Lucy
#
#         Sex   Age  relatives  Parch        Ticket      Fare    Cabin Embarked
# 177  female  50.0          0      0      PC 17595   28.7125      C49        C
# 259  female  50.0          0      1        230433   26.0000      NaN        S
# 299  female  50.0          0      1      PC 17558  247.5208  B58 B60        C
# 458  female  50.0          0      0  F.C.C. 13531   10.5000      NaN        S
# 526  female  50.0          0      0   W./C. 14258   10.5000      NaN        S

# %%
data.loc[(data["Age"]==50)&(data["Fare"]>=200)]
# Out:
#       id  Survived  Pclass                                             Name  \
# 299  300         1       1  Baxter, Mrs. James (Helene DeLaudeniere Chaput)
#
#         Sex   Age  relatives  Parch    Ticket      Fare    Cabin Embarked
# 299  female  50.0          0      1  PC 17558  247.5208  B58 B60        C

# %%
data.isnull().sum()
# Out:
# id             0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age          177
# relatives      0
# Parch          0
# Ticket         0
# Fare           0
# Cabin        687
# Embarked       2
# dtype: int64

# %% [markdown]
# how to handle null values
# *first calculate the ,ean of that col. and fill it in the null values
# *if that col. is not relevant then drop it

# %%
data.loc[(data["Embarked"]=="C")|(data["Embarked"]=="Q")]
# Out:
#       id  Survived  Pclass                                               Name  \
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 5      6         0       3                                   Moran, Mr. James
# 9     10         1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 16    17         0       3                               Rice, Master. Eugene
# 19    20         1       3                            Masselmani, Mrs. Fatima
# ..   ...       ...     ...                                                ...
# 875  876         1       3                   Najib, Miss. Adele Kiamie "Jane"
# 879  880         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885  886         0       3               Rice, Mrs. William (Margaret Norton)
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# functions and descripitive

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         891 non-null    int64
#  1   Survived   891 non-null    int64
#  2   Pclass     891 non-null    int64
#  3   Name       891 non-null    object
#  4   Sex        891 non-null    object
#  5   Age        714 non-null    float64
#  6   relatives  891 non-null    int64
#  7   Parch      891 non-null    int64
#  8   Ticket     891 non-null    object
#  9   Fare       891 non-null    float64
#  10  Cabin      204 non-null    object
#  11  Embarked   889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#                id    Survived      Pclass         Age   relatives       Parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean   446.000000    0.383838    2.308642   29.699118    0.523008    0.381594
# std    257.353842    0.486592    0.836071   14.526497    1.102743    0.806057
# min      1.000000    0.000000    1.000000    0.420000    0.000000    0.000000
# 25%    223.500000    0.000000    2.000000   20.125000    0.000000    0.000000
# 50%    446.000000    0.000000    3.000000   28.000000    0.000000    0.000000
# 75%    668.500000    1.000000    3.000000   38.000000    1.000000    0.000000
# max    891.000000    1.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
data["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
data["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data["Age"].max()
# Out:
# 80.0

# %%
data.loc[data["Age"]==80,:]
# Out:
#       id  Survived  Pclass                                  Name   Sex   Age  \
# 630  631         1       1  Barkworth, Mr. Algernon Henry Wilson  male  80.0
#
#      relatives  Parch Ticket  Fare Cabin Embarked
# 630          0      0  27042  30.0   A23        S

# %%
data["Age"].min()
# Out:
# 0.42

# %%
data.loc[data["Age"]==0.42,:]
# Out:
#       id  Survived  Pclass                             Name   Sex   Age  \
# 803  804         1       3  Thomas, Master. Assad Alexander  male  0.42
#
#      relatives  Parch Ticket    Fare Cabin Embarked
# 803          0      1   2625  8.5167   NaN        C

# %%
data["Age"].mean()
# Out:
# 29.69911764705882

# %%
def cube(a):
    x = a**3
    return x
cube(2)
# Out:
# 8

# %%
cube = lambda a:a**3
cube(2)
# Out:
# 8

# %% [markdown]
# split function

# %%
s = "python can be@used in any field"
c= s.split('@')
c
# Out:
# ['python can be', 'used in any field']

# %%
def extractlastname(name):
    x = name.split(",")
    return (x[1])

data['first_name']= data["Name"].apply(extractlastname)

# %%
data
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
data["Encoded"] =data["Sex"].map({"male":1,"female":0})
data
# Out:
#       id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
x = (3/4)
print (x)
# Out:
# 0.75

# %%
x = 6
y=10
print(x+y)
# Out:
# 16
